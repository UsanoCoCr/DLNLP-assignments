# %%
""" {1000: 0},
{10000: 0},
{100000: 0.01643},
{500000: 0.04859},
{1000000: 0.11669},
{2000000: 0.25631},
{5000000：0.75912},
{8000000: 1.04655},
{10000000: 1.12554} """

import numpy as np
import matplotlib.pyplot as plt

# visualize the flatten_list function performance
scale_of_input = [1000, 10000, 100000, 500000, 1000000, 2000000, 5000000, 8000000, 10000000]
time = [0, 0, 0.01643, 0.04859, 0.11669, 0.25631, 0.75912, 1.04655, 1.12554]

plt.plot(scale_of_input, time)
plt.xlabel('Scale of input')
plt.ylabel('Time (s)')
plt.title('Performance of flatten_list function')
plt.show()

plt.savefig('flatten_list_performance.png')

# %%
""" {1000: 0},
{10000: 0},
{100000: 0.01365},
{500000: 0.03120},
{1000000: 0.06614},
{2000000: 0.11780},
{5000000：0.35164},
{8000000: 0.53242},
{10000000: 0.67613} """

scale_of_input = [1000, 10000, 100000, 500000, 1000000, 2000000, 5000000, 8000000, 10000000]
time = [0, 0, 0.01365, 0.03120, 0.06614, 0.11780, 0.35164, 0.53242, 0.67613]

plt.plot(scale_of_input, time)
plt.xlabel('Scale of input')
plt.ylabel('Time (s)')
plt.title('Performance of char_count function')
plt.show()

# %%
""" Epoch: 01
        Train Loss: 1.115 | Train Acc: 61.52%
        Val Loss: 1.011 | Val Acc: 72.12%
Epoch: 02
        Train Loss: 0.886 | Train Acc: 85.74%
        Val Loss: 0.970 | Val Acc: 76.29%
Epoch: 03
        Train Loss: 0.819 | Train Acc: 92.55%
        Val Loss: 0.967 | Val Acc: 76.88%
Epoch: 04
        Train Loss: 0.796 | Train Acc: 94.73%
        Val Loss: 0.956 | Val Acc: 78.27%
Epoch: 05
        Train Loss: 0.784 | Train Acc: 95.95%
        Val Loss: 0.962 | Val Acc: 77.68%
Early stopping at epoch 4
Test Loss: 0.948 | Test Acc: 78.97% """

train_loss = [1.115, 0.886, 0.819, 0.796, 0.784]
train_acc = [61.52, 85.74, 92.55, 94.73, 95.95]
val_loss = [1.011, 0.970, 0.967, 0.956, 0.962]
val_acc = [72.12, 76.29, 76.88, 78.27, 77.68]

plt.plot(range(1, 6), train_loss, label='Train Loss')
plt.plot(range(1, 6), val_loss, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss of training and validation set')
plt.show()

# %%
train_acc = [61.52, 85.74, 92.55, 94.73, 95.95]
val_acc = [72.12, 76.29, 76.88, 78.27, 77.68]

plt.plot(range(1, 6), train_acc, label='Train Acc')
plt.plot(range(1, 6), val_acc, label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.title('Accuracy of training and validation set')

plt.show()
